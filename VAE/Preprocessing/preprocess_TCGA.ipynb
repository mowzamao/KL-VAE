# %% [markdown]
# # Preprocessing TCGA Data

# %%
import os
import numpy as np
import pandas as pd
import glob
from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('ticks')
sns.set_context('paper')

from tabulate import tabulate
from sklearn.preprocessing import MinMaxScaler

# %%
tcga_path = "/mnt/c/Users/owlsa/Documents/GitHub/cits4010/data/TCGA"
raw_data_path = "/mnt/c/Users/owlsa/Documents/GitHub/cits4010/data/TCGA/raw_data"
processed_data_path = "/mnt/c/Users/owlsa/Documents/GitHub/cits4010/data/TCGA/processed_data"
clinical_data_path = "/mnt/c/Users/owlsa/Documents/GitHub/cits4010/data/TCGA/clinical/clinical.tsv"

# %% [markdown]
# # Verifying files

# %% [markdown]
# Reading the clinical data for the entire TCGA project

# %% [markdown]
# ## Preprocessing the Clinical Data

# %%
clinical_data = pd.read_table(clinical_data_path, delimiter='\t')

# drop uneeded columns
cols = clinical_data.columns.drop(["case_submitter_id", "project_id", "age_at_index", "gender", "race", "tissue_or_organ_of_origin", "site_of_resection_or_biopsy", "primary_diagnosis", "ajcc_pathologic_stage"])
clinical_data = clinical_data.drop(columns=cols)

# convert nulls to 0s
clinical_data = clinical_data.replace(["'--", "Not Reported", "not reported"], '0') # encode missing data with 0
clinical_data = clinical_data.drop_duplicates(ignore_index=True)

# convert dtypes
clinical_data['age_at_index'] = clinical_data['age_at_index'].apply(pd.to_numeric, downcast='integer')
clinical_data = clinical_data.convert_dtypes(infer_objects=True)

clinical_data.head()
# Out:
#   case_submitter_id project_id  age_at_index gender   race  \
# 0      TCGA-DD-AAVP  TCGA-LIHC            48   male  asian
# 1      TCGA-KK-A7B2  TCGA-PRAD            68   male  white
# 2      TCGA-DC-6158  TCGA-READ            70   male  white
# 3      TCGA-DD-A4NP  TCGA-LIHC            32   male  white
# 4      TCGA-HQ-A5ND  TCGA-BLCA            78   male      0
#
#   ajcc_pathologic_stage              primary_diagnosis  \
# 0               Stage I  Hepatocellular carcinoma, NOS
# 1                     0            Adenocarcinoma, NOS
# 2               Stage I            Adenocarcinoma, NOS
# 3               Stage I  Hepatocellular carcinoma, NOS
# 4              Stage IV    Transitional cell carcinoma
#
#   site_of_resection_or_biopsy tissue_or_organ_of_origin
# 0                       Liver                     Liver
# 1              Prostate gland            Prostate gland
# 2                 Rectum, NOS               Rectum, NOS
# 3                       Liver                     Liver
# 4                Bladder, NOS              Bladder, NOS

# %% [markdown]
# Helper function for counting the values in each column of the df and outputting the results as tables

# %%
categorical_columns = ['gender', 'race', 'ajcc_pathologic_stage', 'primary_diagnosis', 
                       'site_of_resection_or_biopsy', 'tissue_or_organ_of_origin']
def get_column_counts(df):
    for col in categorical_columns:
        data = pd.DataFrame(df[col].value_counts())
        print(col)
        print(tabulate(data, headers=['Field', 'Count'], tablefmt='simple_grid'))

get_column_counts(clinical_data)
# Out:
# gender
# ┌─────────┬─────────┐
# │ Field   │   Count │
# ├─────────┼─────────┤
# │ female  │    5365 │
# ├─────────┼─────────┤
# │ male    │    4982 │
# ├─────────┼─────────┤
# │ 0       │      39 │
# └─────────┴─────────┘
# race
# ┌───────────────────────────────────────────┬─────────┐
# │ Field                                     │   Count │
# ├───────────────────────────────────────────┼─────────┤
# │ white                                     │    7791 │
# ├───────────────────────────────────────────┼─────────┤
# │ 0                                         │     973 │
# ├───────────────────────────────────────────┼─────────┤
# │ black or african american                 │     923 │
# ├───────────────────────────────────────────┼─────────┤
# │ asian                                     │     660 │
# ├───────────────────────────────────────────┼─────────┤
# │ american indian or alaska native          │      26 │
# ├───────────────────────────────────────────┼─────────┤
# │ native hawaiian or other pacific islander │      13 │
# └───────────────────────────────────────────┴─────────┘
# ajcc_pathologic_stage
# ┌────────────┬─────────┐
# │ Field      │   Count │
# ├────────────┼─────────┤
# │ 0          │    3589 │
# ├────────────┼─────────┤
# │ Stage I    │    1240 │
# ├────────────┼─────────┤
# │ Stage IIA  │     797 │
# ├────────────┼─────────┤
# │ Stage IIB  │     694 │
# ├────────────┼─────────┤
# │ Stage III  │     692 │
# ├────────────┼─────────┤
# │ Stage II   │     615 │
# ├────────────┼─────────┤
# │ Stage IIIA │     500 │
# ├────────────┼─────────┤
# │ Stage IV   │     467 │
# ├────────────┼─────────┤
# │ Stage IB   │     399 │
# ├────────────┼─────────┤
# │ Stage IA   │     381 │
# ├────────────┼─────────┤
# │ Stage IVA  │     331 │
# ├────────────┼─────────┤
# │ Stage IIIB │     276 │
# ├────────────┼─────────┤
# │ Stage IIIC │     246 │
# ├────────────┼─────────┤
# │ Stage IIC  │      67 │
# ├────────────┼─────────┤
# │ Stage IS   │      46 │
# ├────────────┼─────────┤
# │ Stage IVB  │      19 │
# ├────────────┼─────────┤
# │ Stage X    │      13 │
# ├────────────┼─────────┤
# │ Stage 0    │       7 │
# ├────────────┼─────────┤
# │ Stage IVC  │       7 │
# └────────────┴─────────┘
# primary_diagnosis
# ┌───────────────────────────────────────────────────────────┬─────────┐
# │ Field                                                     │   Count │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Adenocarcinoma, NOS                                       │    1589 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Squamous cell carcinoma, NOS                              │    1170 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Infiltrating duct carcinoma, NOS                          │     929 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Papillary adenocarcinoma, NOS                             │     677 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Serous cystadenocarcinoma, NOS                            │     550 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Clear cell adenocarcinoma, NOS                            │     523 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Malignant melanoma, NOS                                   │     421 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Endometrioid adenocarcinoma, NOS                          │     404 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Hepatocellular carcinoma, NOS                             │     355 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Transitional cell carcinoma                               │     338 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Lobular carcinoma, NOS                                    │     201 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Glioblastoma                                              │     162 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Acute myeloid leukemia, NOS                               │     151 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Mucinous adenocarcinoma                                   │     135 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Mixed glioma                                              │     131 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Astrocytoma, anaplastic                                   │     130 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Adenocarcinoma with mixed subtypes                        │     116 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Oligodendroglioma, NOS                                    │     112 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Pheochromocytoma, NOS                                     │     110 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Papillary carcinoma, follicular variant                   │     105 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Squamous cell carcinoma, keratinizing, NOS                │     103 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Leiomyosarcoma, NOS                                       │     101 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Adenocarcinoma, intestinal type                           │      80 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Tubular adenocarcinoma                                    │      80 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │
       3 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Micropapillary carcinoma, NOS                             │       3 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Bronchiolo-alveolar adenocarcinoma, NOS                   │       3 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Myxoid leiomyosarcoma                                     │       3 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Pleomorphic carcinoma                                     │       3 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Paget disease and infiltrating duct carcinoma of breast   │       3 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Acral lentiginous melanoma, malignant                     │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Lentigo maligna melanoma                                  │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Paraganglioma, malignant                                  │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Thymoma, type A, NOS                                      │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Synovial sarcoma, NOS                                     │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Synovial sarcoma, biphasic                                │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Pleomorphic liposarcoma                                   │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Teratocarcinoma                                           │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Papillary carcinoma, NOS                                  │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Endometrioid adenocarcinoma, secretory variant            │       2 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Large cell neuroendocrine carcinoma                       │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Secretory carcinoma of breast                             │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Thymoma, type B1, NOS                                     │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Squamous cell carcinoma, small cell, nonkeratinizing      │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Apocrine adenocarcinoma                                   │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Adenoid cystic carcinoma                                  │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Abdominal fibromatosis                                    │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Phyllodes tumor, malignant                                │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Follicular carcinoma, minimally invasive                  │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Hepatocellular carcinoma, spindle cell variant            │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Liposarcoma, well differentiated                          │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Mesodermal mixed tumor                                    │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Cribriform carcinoma, NOS                                 │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Fibrous mesothelioma, malignant                           │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Oxyphilic adenocarcinoma                                  │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Squamous cell carcinoma, spindle cell                     │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Desmoplastic melanoma, malignant                          │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Follicular adenocarcinoma, NOS                            │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Adenocarcinoma with neuroendocrine differentiation        │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Basal cell carcinoma, NOS                                 │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Aggressive fibromatosis                                   │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Cystadenocarcinoma, NOS                                   │       1 │
# ├───────────────────────────────────────────────────────────┼─────────┤
# │ Serous surface papillary carcinoma                        │       1 │
# └───────────────────────────────────────────────────────────┴─────────┘
# site_of_resection_or_biopsy
# ┌────────────────────────────────────────────────────────────────────────────┬─────────┐
# │ Field                                                                      │   Count │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Breast, NOS                                                                │    1085 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Kidney, NOS                                                                │     891 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Upper lobe, lung                                                           │     563 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Endometrium                                                                │     561 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Thyroid gland                                                              │     507 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Prostate gland                                                             │     497 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Cerebrum                                                                   │     439 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Ovary                                                                      │     417 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Liver                                                                      │     373 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Lower lobe, lung                                                           │     353 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Cervix uteri                                                               │     299 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Bladder, NOS                                                               │     234 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Brain, NOS                                                                 │     227 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Bone marrow                                                                │     151 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Gastric antrum                                                             │     150 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Adrenal gland, NOS                                                         │     150 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Testis, NOS                                                                │     135 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Head of pancreas                                                           │     130 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Tongue, NOS                                                                │     128 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Lower third of esophagus                                                   │     122 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Larynx, NOS                                                                │     116 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Retroperitoneum                                                            │     113 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Sigmoid colon                                                              │     112 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Colon, NOS                                                                 │     106 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Cardia, NOS                                                                │     102 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Body of stomach                                                            │      98 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Cecum                                                                      │      96 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Lymph nodes of axilla or arm                                               │      96 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Thymus                                                                     │      90 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Rectum, NOS                                                                │      88 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Pleura, NOS                                                                │      86 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Ascending colon                                                            │      85 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Cortex of adrenal gland                                                    │      79 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Rectosigmoid junction                                                      │      76 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Connective, subcutaneous and other soft tissues of lower limb and hip      │      75 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Overlapping lesion of lip, oral cavity and pharynx                         │      70 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Choroid                                                                    │      67 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Lateral wall of bladder                                                    │      63 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Lymph nodes of inguinal region or leg                                      │      54 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Lung, NOS                                                                  │      53 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │
       1 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Parietal lobe                                                              │       1 │
# ├────────────────────────────────────────────────────────────────────────────┼─────────┤
# │ Gallbladder                                                                │       1 │
# └────────────────────────────────────────────────────────────────────────────┴─────────┘

# %% [markdown]
# Scale Age Data

# %%
scaler = MinMaxScaler()
clinical_data['age_at_index'] = scaler.fit_transform(clinical_data['age_at_index'].values.reshape(-1, 1))

# %% [markdown]
# One-hot encoding text data

# %%
categorical_columns = pd.get_dummies(clinical_data.drop(columns=['age_at_index', 'case_submitter_id', 'project_id']), drop_first=True)
clinical_data = pd.concat([clinical_data[['age_at_index', 'case_submitter_id', 'project_id']], categorical_columns], axis=1)

# %% [markdown]
# ## Splitting the data by project

# %% [markdown]
# Separating the clinical data by the specific TCGA project (e.g. TCGA ACC, TCGA OV)

# %%
# separate the clinical data by project
project_clinical_data = {}
project_names = sorted([project.replace('TCGA-', '') for project in set(clinical_data['project_id'].values)])

# %%
project_names
# Out:
# ['ACC',
#  'BLCA',
#  'BRCA',
#  'CESC',
#  'CHOL',
#  'COAD',
#  'DLBC',
#  'ESCA',
#  'GBM',
#  'HNSC',
#  'KICH',
#  'KIRC',
#  'KIRP',
#  'LAML',
#  'LGG',
#  'LIHC',
#  'LUAD',
#  'LUSC',
#  'MESO',
#  'OV',
#  'PAAD',
#  'PCPG',
#  'PRAD',
#  'READ',
#  'SARC',
#  'SKCM',
#  'STAD',
#  'TGCT',
#  'THCA',
#  'THYM',
#  'UCEC',
#  'UCS',
#  'UVM']

# %% [markdown]
# Reading the sample sheets from each TCGA directory (there is one per project)

# %%
sample_sheets = []

for project_name in project_names:
    file_pattern = os.path.join(raw_data_path, project_name, 'gdc_sample_sheet.*.tsv')
    file_name = glob.glob(file_pattern)
    sample_sheet = pd.read_table(file_name[0])
    sample_sheets.append(sample_sheet)

sample_sheet = pd.concat([s for s in sample_sheets], axis=0, join='inner')

sample_sheet = sample_sheet.drop(columns=['Data Category', 'Data Type'])
sample_sheet = sample_sheet.replace(["'--", "Not Reported", "not reported"], '0') # encode missing data with 0

sample_sheet = sample_sheet.convert_dtypes(infer_objects=True)
sample_sheet = pd.concat([sample_sheet, pd.get_dummies(sample_sheet['Sample Type'], prefix='Sample Type')], axis=1)
sample_sheet = sample_sheet.drop(columns=['Sample Type'])
sample_sheet
# Out:
#                                  File ID  \
# 0   674f8521-6181-49a9-b32c-729d83d0b8bd
# 1   7069c2e2-9e61-45ba-9f14-75bd90b5d6ec
# 2   251e5d31-2d8d-4858-9b82-c78548e6987b
# 3   66e177ca-c09a-462d-a025-1e9d003ee9e9
# 4   a3365732-0ae5-4536-aa3a-5f57447ffffb
# ..                                   ...
# 75  8c5e6f18-3a16-4065-ab12-d3391da154e9
# 76  ea09a6c8-0521-4b9e-8cc0-ba0e7f855aa8
# 77  ddf84756-4ed2-4deb-9321-9fc456232cdc
# 78  b5213c67-a73f-4b3d-ac9b-deedfbc08160
# 79  7b0ba77b-5af5-4529-995a-18ef231c0b41
#
#                                             File Name Project ID  \
# 0   4100a850-68a9-4bb9-ae91-dd63d64cb1aa.rna_seq.a...   TCGA-ACC
# 1   8026738f-cc73-4c9e-be15-28366f272caa.rna_seq.a...   TCGA-ACC
# 2   dd76dd00-b1e5-4245-8059-6b2966cf257d.rna_seq.a...   TCGA-ACC
# 3   925136ec-3825-49cd-8aa3-1c536e4a410c.rna_seq.a...   TCGA-ACC
# 4   2efca6e0-4edb-42a2-9d3a-ee8f25624bf9.rna_seq.a...   TCGA-ACC
# ..                                                ...        ...
# 75  61b1ca49-d26b-432d-bc34-98c4644f8b4f.rna_seq.a...   TCGA-UVM
# 76  8acb6203-ddd0-4edc-8017-7e3b2953b7a2.rna_seq.a...   TCGA-UVM
# 77  a199f5da-dda7-406f-967b-f9c5ff771a40.rna_seq.a...   TCGA-UVM
# 78  97aede8f-8315-4d49-8f04-41b4c266d78c.rna_seq.a...   TCGA-UVM
# 79  74e2edb8-5d55-48b2-a24d-2d76db8a04bd.rna_seq.a...   TCGA-UVM
#
#          Case ID         Sample ID  Sample Type_Additional - New Primary  \
# 0   TCGA-OR-A5K2  TCGA-OR-A5K2-01A                                 False
# 1   TCGA-OR-A5LN  TCGA-OR-A5LN-01A                                 False
# 2   TCGA-OR-A5JG  TCGA-OR-A5JG-01A                                 False
# 3   TCGA-OR-A5KX  TCGA-OR-A5KX-01A                                 False
# 4   TCGA-OR-A5LR  TCGA-OR-A5LR-01A                                 False
# ..           ...               ...                                   ...
# 75  TCGA-VD-A8KK  TCGA-VD-A8KK-01A                                 False
# 76  TCGA-V4-A9EJ  TCGA-V4-A9EJ-01A                                 False
# 77  TCGA-V4-A9EW  TCGA-V4-A9EW-01A                                 False
# 78  TCGA-VD-AA8P  TCGA-VD-AA8P-01A                                 False
# 79  TCGA-V4-A9EH  TCGA-V4-A9EH-01A                                 False
#
#     Sample Type_Additional Metastatic  Sample Type_Metastatic  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
# ..                                ...                     ...
# 75                              False                   False
# 76                              False                   False
# 77                              False                   False
# 78                              False                   False
# 79                              False                   False
#
#     Sample Type_Primary Blood Derived Cancer - Peripheral Blood  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ..                                                ...
# 75                                              False
# 76                                              False
# 77                                              False
# 78                                              False
# 79                                              False
#
#     Sample Type_Primary Tumor  Sample Type_Recurrent Tumor  \
# 0                        True                        False
# 1                        True                        False
# 2                        True                        False
# 3                        True                        False
# 4                        True                        False
# ..                        ...                          ...
# 75                       True                        False
# 76                       True                        False
# 77                       True                        False
# 78                       True                        False
# 79                       True                        False
#
#     Sample Type_Solid Tissue Normal
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
# ..                              ...
# 75                            False
# 76                            False
# 77                            False
# 78                            False
# 79                            False
#
# [11275 rows x 12 columns]

# %%
joined_data = sample_sheet.merge(clinical_data, left_on='Case ID', right_on='case_submitter_id', how='left', validate='many_to_one').reset_index()
joined_data = joined_data.drop(columns=['File ID','project_id', 'Project ID', 'Case ID', 'Sample ID', 'case_submitter_id', 'index'])
joined_data['File Name'] = joined_data['File Name'].str.replace('.rna_seq.augmented_star_gene_counts.tsv', '')
joined_data = joined_data.set_index('File Name')
joined_data
# Out:
#                                       Sample Type_Additional - New Primary  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                 False
# 8026738f-cc73-4c9e-be15-28366f272caa                                 False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                 False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                 False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                 False
# ...                                                                    ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                 False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                 False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                 False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                 False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                 False
#
#                                       Sample Type_Additional Metastatic  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                              False
# 8026738f-cc73-4c9e-be15-28366f272caa                              False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                              False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                              False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                              False
# ...                                                                 ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                              False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                              False
# a199f5da-dda7-406f-967b-f9c5ff771a40                              False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                              False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                              False
#
#                                       Sample Type_Metastatic  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                   False
# 8026738f-cc73-4c9e-be15-28366f272caa                   False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                   False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                   False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                   False
# ...                                                      ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                   False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                   False
# a199f5da-dda7-406f-967b-f9c5ff771a40                   False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                   False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                   False
#
#                                       Sample Type_Primary Blood Derived Cancer - Peripheral Blood  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                              False
# 8026738f-cc73-4c9e-be15-28366f272caa                                              False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                              False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                              False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                              False
# ...                                                                                 ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                              False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                              False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                              False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                              False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                              False
#
#                                       Sample Type_Primary Tumor  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                       True
# 8026738f-cc73-4c9e-be15-28366f272caa                       True
# dd76dd00-b1e5-4245-8059-6b2966cf257d                       True
# 925136ec-3825-49cd-8aa3-1c536e4a410c                       True
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                       True
# ...                                                         ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                       True
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                       True
# a199f5da-dda7-406f-967b-f9c5ff771a40                       True
# 97aede8f-8315-4d49-8f04-41b4c266d78c                       True
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                       True
#
#                                       Sample Type_Recurrent Tumor  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                        False
# 8026738f-cc73-4c9e-be15-28366f272caa                        False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                        False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                        False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                        False
# ...                                                           ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                        False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                        False
# a199f5da-dda7-406f-967b-f9c5ff771a40                        False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                        False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                        False
#
#                                       Sample Type_Solid Tissue Normal  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                            False
# 8026738f-cc73-4c9e-be15-28366f272caa                            False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                            False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                            False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                            False
# ...                                                               ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                            False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                            False
# a199f5da-dda7-406f-967b-f9c5ff771a40                            False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                            False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                            False
#
#                                       age_at_index  gender_female  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa      0.355556           True
# 8026738f-cc73-4c9e-be15-28366f272caa      0.344444           True
# dd76dd00-b1e5-4245-8059-6b2966cf257d      0.677778          False
# 925136ec-3825-49cd-8aa3-1c536e4a410c      0.277778           True
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9      0.333333           True
# ...                                            ...            ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f      0.600000          False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2      0.422222          False
# a199f5da-dda7-406f-967b-f9c5ff771a40      0.488889           True
# 97aede8f-8315-4d49-8f04-41b4c266d78c      0.711111           True
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd      0.588889          False
#
#                                       gender_male  ...  \
# File Name                                          ...
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa        False  ...
# 8026738f-cc73-4c9e-be15-28366f272caa        False  ...
# dd76dd00-b1e5-4245-8059-6b2966cf257d         True  ...
# 925136ec-3825-49cd-8aa3-1c536e4a410c        False  ...
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9        False  ...
# ...                                           ...  ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f         True  ...
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2         True  ...
# a199f5da-dda7-406f-967b-f9c5ff771a40        False  ...
# 97aede8f-8315-4d49-8f04-41b4c266d78c        False  ...
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd         True  ...
#
#                                       tissue_or_organ_of_origin_Trigone of bladder  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                         False
# 8026738f-cc73-4c9e-be15-28366f272caa                                         False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                         False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                         False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                         False
# ...                                                                            ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                         False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                         False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                         False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                         False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                         False
#
#                                       tissue_or_organ_of_origin_Unknown primary site  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                           False
# 8026738f-cc73-4c9e-be15-28366f272caa                                           False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                           False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                           False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                           False
# ...                                                                              ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                           False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                           False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                           False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                           False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                           False
#
#                                       tissue_or_organ_of_origin_Upper Gum  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                False
# 8026738f-cc73-4c9e-be15-28366f272caa                                False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                False
# ...                                                                   ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                False
#
#                                       tissue_or_organ_of_origin_Upper lobe, lung  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                       False
# 8026738f-cc73-4c9e-be15-28366f272caa                                       False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                       False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                       False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                       False
# ...                                                                          ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                       False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                       False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                       False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                       False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                       False
#
#                                       tissue_or_organ_of_origin_Upper third of esophagus  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                              False
# 8026738f-cc73-4c9e-be15-28366f272caa                                              False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                              False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                              False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                              False
# ...                                                                                 ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                              False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                              False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                              False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                              False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                              False
#
#                                       tissue_or_organ_of_origin_Upper-inner quadrant of breast  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                              False
# 8026738f-cc73-4c9e-be15-28366f272caa                                              False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                              False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                              False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                              False
# ...                                                                                 ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                              False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                              False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                              False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                              False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                              False
#
#                                       tissue_or_organ_of_origin_Upper-outer quadrant of breast  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                              False
# 8026738f-cc73-4c9e-be15-28366f272caa                                              False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                              False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                              False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                              False
# ...                                                                                 ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                              False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                              False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                              False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                              False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                              False
#
#                                       tissue_or_organ_of_origin_Ureteric orifice  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                       False
# 8026738f-cc73-4c9e-be15-28366f272caa                                       False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                       False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                       False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                       False
# ...                                                                          ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                       False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                       False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                       False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                       False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                       False
#
#                                       tissue_or_organ_of_origin_Uterus, NOS  \
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                  False
# 8026738f-cc73-4c9e-be15-28366f272caa                                  False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                  False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                  False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                  False
# ...                                                                     ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                  False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                  False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                  False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                  False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                  False
#
#                                       tissue_or_organ_of_origin_Ventral surface of tongue, NOS
# File Name
# 4100a850-68a9-4bb9-ae91-dd63d64cb1aa                                              False
# 8026738f-cc73-4c9e-be15-28366f272caa                                              False
# dd76dd00-b1e5-4245-8059-6b2966cf257d                                              False
# 925136ec-3825-49cd-8aa3-1c536e4a410c                                              False
# 2efca6e0-4edb-42a2-9d3a-ee8f25624bf9                                              False
# ...                                                                                 ...
# 61b1ca49-d26b-432d-bc34-98c4644f8b4f                                              False
# 8acb6203-ddd0-4edc-8017-7e3b2953b7a2                                              False
# a199f5da-dda7-406f-967b-f9c5ff771a40                                              False
# 97aede8f-8315-4d49-8f04-41b4c266d78c                                              False
# 74e2edb8-5d55-48b2-a24d-2d76db8a04bd                                              False
#
# [11275 rows x 464 columns]

# %%
joined_data.to_pickle(processed_data_path+f'/clinical_data/clinical_data.pkl')

# %% [markdown]
# # Collating Gene Expression

# %%
# getting a list of genes
gene_info = pd.read_table('C:/Users/owlsa/Documents/GitHub/cits4010/data/TCGA/raw_data/BRCA/0a7dc8b9-4196-41d3-ada1-a50cb36bfd2b/3c9c665e-9327-45f0-b412-224e8948deb2.rna_seq.augmented_star_gene_counts.tsv', header=1, usecols=['gene_id', 'gene_name', 'gene_type'])
gene_info = gene_info.drop(index=[0, 1, 2, 3])
gene_info = gene_info.set_index('gene_id', drop=True)
gene_info.to_csv('gene_info.csv')

# %%
# for project_name in project_names:
#     project_dir = os.path.join(raw_data_path, project_name)

#     # get file names from directory
#     file_pattern = os.path.join(project_dir,"*", '*.rna_seq.augmented_star_gene_counts.tsv')
#     file_list = glob.glob(file_pattern)
    
#     num_merges = 0
#     for file in file_list:
#         df = pd.read_table(file, header=1, usecols=['gene_id', 'unstranded'], index_col='gene_id')
#         df = df.drop(index=['N_unmapped', 'N_multimapping', 'N_noFeature', 'N_ambiguous'])
#         df = df.rename(columns={'unstranded': str(os.path.basename(file)).replace('.rna_seq.augmented_star_gene_counts.tsv', '')})
#         gene_info = gene_info.merge(df, how='left', left_index=True, right_index=True, validate='one_to_one')
#         num_merges += 1
        
#     print(f"Added {num_merges} {project_name} files to dataframe")

# %%
def normalise(df):
    housekeeping_genes = ["ENSG00000111640.15", "ENSG00000075624.17", "ENSG00000134644.16", "ENSG00000150991.15"]

    exp = df.copy()
    for col in exp.columns:
        sm: float = 0
        cnt = 0
        for gene in housekeeping_genes:
            if gene not in exp.index:
                continue
            sm += exp.at[gene, col]
            cnt += 1

        mean = sm / cnt
        exp[col] = exp[col].astype(float)
        exp.loc[:, col] = exp.loc[:, col] / mean

    exp = np.log(exp+1)
    return exp

# %%
# for project_name in project_names:
#     project_dir = os.path.join(raw_data_path, project_name)
#     file_pattern = os.path.join(project_dir,"*", '*.rna_seq.augmented_star_gene_counts.tsv')
#     file_list = glob.glob(file_pattern)

#     dfs = []
#     for file in file_list:
#         df = pd.read_table(file, header=1, usecols=['gene_id', 'unstranded'], index_col='gene_id')
#         df = df.drop(index=['N_unmapped', 'N_multimapping', 'N_noFeature', 'N_ambiguous'])
#         df = df.rename(columns={'unstranded': str(os.path.basename(file)).replace('.rna_seq.augmented_star_gene_counts.tsv', '')})
#         dfs.append(df)
#     print(f"Read {len(dfs)} files.")

#     df = pd.concat([d for d in dfs], axis=1, join='inner')
#     df = normalise(df)
#     df.to_pickle(processed_data_path+f'/gene_expression_data/{project_name}.pkl')
#     print(f"Saved {project_name} gene expression data")

# %% [markdown]
# # Concatenating Gene Expression and Clinical Data

# %%
clinical_data = pd.read_pickle(processed_data_path+f'/clinical_data/clinical_data.pkl')

# %%
project_names = [
    'ACC',
    'BLCA',
    'BRCA',
    'CESC',
    'CHOL',
    'COAD',
    'DLBC',
    'ESCA',
    'GBM',
    'HNSC',
    'KICH',
    'KIRC',
    'KIRP',
    'LAML',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'MESO',
    'OV',
    'PAAD',
    'PCPG',
    'PRAD',
    'READ',
    'SARC',
    'SKCM',
    'STAD',
    'TGCT',
    'THCA',
    'THYM',
    'UCEC',
    'UCS',
    'UVM'
]

# %%
import gc
import pandas as pd
import numpy as np

# %%
dfs = []
def join_clinical_data(project_name):
    gene_exp = pd.read_pickle(processed_data_path+f'/gene_expression_data/{project_name}.pkl')
    gene_exp = gene_exp.T
    joined = gene_exp.join(clinical_data, how='inner')
    return joined

for project_name in project_names:
    data = join_clinical_data(project_name)
    data = data.to_numpy()
    dfs.append(data)
    print(f"Added {project_name}")
    del data
    gc.collect()
# Out:
# Added ACC
# Added BLCA
# Added BRCA
# Added CESC
# Added CHOL
# Added COAD
# Added DLBC
# Added ESCA
# Added GBM
# Added HNSC
# Added KICH
# Added KIRC
# Added KIRP
# Added LAML
# Added LGG
# Added LIHC
# Added LUAD
# Added LUSC
# Added MESO
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
VAE_data = pd.concat([df for df in dfs], axis=0, join='inner')
VAE_data.to_pickle('VAE_data')
